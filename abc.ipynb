# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 15.0, 250)

plt.hist(x, 256)
plt.show()

# %%
print("Hello")
# Out:
# Hello

# %%
print(x)
# Out:
# [ 5.73101011  9.08537305  8.88408108  6.12620627  7.14939927  3.49970652
#   9.00490307 10.98418133  6.31054186  5.59717425  2.68746811  5.60979828
#   7.07015101  2.71834491 11.57372288  8.42843892 13.53490826  4.76749626
#  14.21889657  6.82650928 11.21376486  8.51950481  8.80968838  5.80501606
#   0.27151057  1.68363964  8.88676756  5.08845648  7.28363419  7.87184289
#  12.18769452  9.73045106  4.29015615  6.29479886 13.20446088  0.04042659
#   4.24817752 11.56570309  7.13954589  5.25112148  4.77267413  1.36412706
#  12.27337644 13.23247999  9.17953107  8.30761479 13.59134984  2.47733224
#  14.12806121 14.4043438  14.68140431 12.33332165  9.52256493  9.61143472
#  12.83023043  7.70991332  3.32908732  9.54483614 11.54647992  5.88789978
#   6.57930144  8.34981491  3.04829275  6.70174558  3.26902171 11.24371858
#   8.15175979 12.51977828 13.75936367 12.33644263  2.41369015 11.6591312
#  11.86208101  4.13139097  4.87469237 14.51137933  9.17357583  7.17319535
# ...
