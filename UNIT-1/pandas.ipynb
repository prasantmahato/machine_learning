# %% [markdown]
# ## Working with Pandas (panel data)
# ### Python Data analysis

# %%
import pandas as pd

# %%
## one column in pandas is called series, & dataframe is a collection of series
# dataframe holds entrire data rows
df = pd.read_csv("../ml_datasets/Salaries.csv")

# %%
# Last 5 data
df.tail()
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 392         393      Prof          A             33           30  Male  103106
# 393         394      Prof          A             31           19  Male  150564
# 394         395      Prof          A             42           25  Male  101738
# 395         396      Prof          A             25           15  Male   95329
# 396         397  AsstProf          A              8            4  Male   81035

# %%
# First 5 data rows by default
df.head()
# Out:
#    Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0           1      Prof          B             19           18  Male  139750
# 1           2      Prof          B             20           16  Male  173200
# 2           3  AsstProf          B              4            3  Male   79750
# 3           4      Prof          B             45           39  Male  115000
# 4           5      Prof          B             40           41  Male  141500

# %%
df.head(12)
# Out:
#     Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 0            1       Prof          B             19           18  Female
# 1            2       Prof          B             20           16  Female
# 2            3   AsstProf          B              4            3  Female
# 3            4       Prof          B             45           39  Female
# 4            5       Prof          B             40           41  Female
# 5            6  AssocProf          B              6            6  Female
# 6            7       Prof          B             30           23  Female
# 7            8       Prof          B             45           45  Female
# 8            9       Prof          B             21           20  Female
# 9           10       Prof          B             18           18  Female
# 10          11  AssocProf          B             12            8  Female
# 11          12   AsstProf          B              7            2  Female
#
#     salary
# ...

# %%
# res = df.loc[(df.sex == 'Female')]
# res

# %% [markdown]
# ### Delete method 1

# %%
df2 = df.copy()
del df2['Unnamed: 0']

# %%
df2
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %% [markdown]
# ### Delete method 2

# %%
# Original Dataset in not affected
df.drop('Unnamed: 0', axis=1)
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
# to have affect on original dataset
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ## Get info about datasets

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rank           397 non-null    object
#  1   discipline     397 non-null    object
#  2   yrs.since.phd  397 non-null    int64
#  3   yrs.service    397 non-null    int64
#  4   sex            397 non-null    object
#  5   salary         397 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 18.7+ KB

# %%
df.shape
# Out:
# (397, 6)

# %%
df.describe()
# Out:
#        yrs.since.phd  yrs.service         salary
# count     397.000000   397.000000     397.000000
# mean       22.314861    17.614610  113706.458438
# std        12.887003    13.006024   30289.038695
# min         1.000000     0.000000   57800.000000
# 25%        12.000000     7.000000   91000.000000
# 50%        21.000000    16.000000  107300.000000
# 75%        32.000000    27.000000  134185.000000
# max        56.000000    60.000000  231545.000000

# %%
df.mean()['salary']
# Out:
# /var/folders/nk/ln22svl57cz_cvk82jt3d1kh0000gn/T/ipykernel_8638/70476129.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()['salary']
# 113706.45843828715

# %%
df.describe(include='all')
# Out:
#         Unnamed: 0  rank discipline  yrs.since.phd  yrs.service   sex  \
# count   397.000000   397        397     397.000000   397.000000   397
# unique         NaN     3          2            NaN          NaN     2
# top            NaN  Prof          B            NaN          NaN  Male
# freq           NaN   266        216            NaN          NaN   358
# mean    199.000000   NaN        NaN      22.314861    17.614610   NaN
# std     114.748275   NaN        NaN      12.887003    13.006024   NaN
# min       1.000000   NaN        NaN       1.000000     0.000000   NaN
# 25%     100.000000   NaN        NaN      12.000000     7.000000   NaN
# 50%     199.000000   NaN        NaN      21.000000    16.000000   NaN
# 75%     298.000000   NaN        NaN      32.000000    27.000000   NaN
# max     397.000000   NaN        NaN      56.000000    60.000000   NaN
#
#                salary
# count      397.000000
# unique            NaN
# top               NaN
# freq              NaN
# ...

# %% [markdown]
# ### Filtering data in DATAFRAME

# %% [markdown]
# ### Get Value of one particular column

# %%
df[['yrs.service', 'salary','sex']].count()
# Out:
# yrs.service    397
# salary         397
# sex            397
# dtype: int64

# %%
df.iloc[:, 1:5:3]
# Out:
#          rank  yrs.service
# 0        Prof           18
# 1        Prof           16
# 2    AsstProf            3
# 3        Prof           39
# 4        Prof           41
# ..        ...          ...
# 392      Prof           30
# 393      Prof           19
# 394      Prof           25
# 395      Prof           15
# 396  AsstProf            4
#
# [397 rows x 2 columns]

# %%
df.iloc[:, [0,3]]
# Out:
#      Unnamed: 0  yrs.since.phd
# 0             1             19
# 1             2             20
# 2             3              4
# 3             4             45
# 4             5             40
# ..          ...            ...
# 392         393             33
# 393         394             31
# 394         395             42
# 395         396             25
# 396         397              8
#
# [397 rows x 2 columns]

# %%
# rows from 300-350
df1 = df.iloc[300:351, :]
df1
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 300         301       Prof          A             39           36    Male
# 301         302       Prof          A             27           16    Male
# 302         303       Prof          A             28           13    Male
# 303         304       Prof          A             14            4    Male
# 304         305       Prof          A             46           44    Male
# 305         306       Prof          A             33           31    Male
# 306         307   AsstProf          A              7            4    Male
# 307         308       Prof          A             31           28    Male
# 308         309   AsstProf          A              5            0    Male
# 309         310       Prof          A             22           15    Male
# 310         311       Prof          A             20            7    Male
# 311         312       Prof          A             14            9    Male
# ...

# %%
df[300:311, ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/lib/python3.10/site-packages/pandas/core/indexes/base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/lib/python3.10/site-packages/pandas/_libs/index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(300, 311, None),)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df[300:311, ]
#
# ...

# %% [markdown]
# #### Labelling Method

# %%
# Only Asst. Prof in between 300-350
df1[df1['rank'] == "AsstProf"]
# Out:
#      Unnamed: 0      rank discipline  yrs.since.phd  yrs.service   sex  salary
# 306         307  AsstProf          A              7            4  Male   74500
# 308         309  AsstProf          A              5            0  Male   74000
# 315         316  AsstProf          B              6            3  Male   84716
# 325         326  AsstProf          B              8            4  Male   84500
# 348         349  AsstProf          B              4            3  Male   80139

# %%
df1[df1['sex'] == 'Female']
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 316         317  AssocProf          B             12            9  Female
# 323         324       Prof          B             24           15  Female
# 332         333       Prof          B             18           10  Female
# 334         335  AssocProf          B             19            6  Female
# 341         342       Prof          B             17           17  Female
#
#      salary
# 316   71065
# 323  161101
# 332  105450
# 334  104542
# 341  124312

# %%
# Salary greater than 1,00,000 and is female
df[(df['salary'] >= 100000) & (df['sex'] == 'Female')]
# Out:
#      Unnamed: 0       rank discipline  yrs.since.phd  yrs.service     sex  \
# 9            10       Prof          B             18           18  Female
# 19           20       Prof          A             39           36  Female
# 47           48       Prof          B             23           19  Female
# 48           49       Prof          B             25           25  Female
# 63           64  AssocProf          B             11           11  Female
# 68           69       Prof          B             17           17  Female
# 84           85       Prof          B             17           18  Female
# 103         104       Prof          B             20           14  Female
# 114         115       Prof          A             12            0  Female
# 148         149       Prof          B             36           26  Female
# 153         154  AssocProf          B             12           10  Female
# 186         187  AssocProf          B             13           10  Female
# ...

# %% [markdown]
# ### Index in Pandas

# %%
df2.index
df2
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %%
df2.set_index('rank') # not reflected on original datasets
# Out:
#          discipline  yrs.since.phd  yrs.service   sex  salary
# rank
# Prof              B             19           18  Male  139750
# Prof              B             20           16  Male  173200
# AsstProf          B              4            3  Male   79750
# Prof              B             45           39  Male  115000
# Prof              B             40           41  Male  141500
# ...             ...            ...          ...   ...     ...
# Prof              A             33           30  Male  103106
# Prof              A             31           19  Male  150564
# Prof              A             42           25  Male  101738
# Prof              A             25           15  Male   95329
# AsstProf          A              8            4  Male   81035
#
# [397 rows x 5 columns]

# %%
df2
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
# [397 rows x 6 columns]

# %% [markdown]
# ### GroupBy
# #### Another way of filtering data

# %%
k = df2.groupby('rank', group_keys=True)

# %%
k1 = k.get_group('AsstProf')
k1
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary
# 2    AsstProf          B              4            3  Male   79750
# 11   AsstProf          B              7            2  Male   79800
# 12   AsstProf          B              1            1  Male   77700
# 13   AsstProf          B              2            0  Male   78000
# 27   AsstProf          B              5            3  Male   82379
# ..        ...        ...            ...          ...   ...     ...
# 359  AsstProf          A             11            4  Male   78785
# 376  AsstProf          A              4            1  Male   74856
# 377  AsstProf          A              6            3  Male   77081
# 380  AsstProf          A              8            3  Male   75996
# 396  AsstProf          A              8            4  Male   81035
#
# [67 rows x 6 columns]

# %% [markdown]
# ## Adding a new column to the Dataframe

# %%
avg_salary = df2['salary'].mean()
df2['SalaryDiffFromAvg'] = round(abs(avg_salary - df2['salary']))

# %%
df2
# Out:
#          rank discipline  yrs.since.phd  yrs.service   sex  salary  \
# 0        Prof          B             19           18  Male  139750
# 1        Prof          B             20           16  Male  173200
# 2    AsstProf          B              4            3  Male   79750
# 3        Prof          B             45           39  Male  115000
# 4        Prof          B             40           41  Male  141500
# ..        ...        ...            ...          ...   ...     ...
# 392      Prof          A             33           30  Male  103106
# 393      Prof          A             31           19  Male  150564
# 394      Prof          A             42           25  Male  101738
# 395      Prof          A             25           15  Male   95329
# 396  AsstProf          A              8            4  Male   81035
#
#      SalaryDiffFromAvg
# 0              26044.0
# 1              59494.0
# 2              33956.0
# 3               1294.0
# 4              27794.0
# ...

# %% [markdown]
# ## Frequency Meseaurement

# %%
df['rank'].value_counts()
# Out:
# Prof         266
# AsstProf      67
# AssocProf     64
# Name: rank, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      358
# Female     39
# Name: sex, dtype: int64

# %%
df['salary'].value_counts()
# Out:
# 92000     5
# 72500     4
# 74000     4
# 105000    3
# 101000    3
#          ..
# 76840     1
# 83001     1
# 113278    1
# 155500    1
# 81035     1
# Name: salary, Length: 371, dtype: int64

# %% [markdown]
# ### Professor getting maximum salary

# %%
df[(df['salary'] == max(df['salary'])) & (df['rank'] == 'Prof')]
# Out:
#     rank discipline  yrs.since.phd  yrs.service   sex  salary
# 43  Prof          B             38           38  Male  231545
