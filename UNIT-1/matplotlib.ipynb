# %% [markdown]
# # Matplotlib

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../ml_datasets/Salaries.csv")

# %%
df['rank'].value_counts()
# Out:
# Prof         266
# AsstProf      67
# AssocProf     64
# Name: rank, dtype: int64

# %% [markdown]
# ### Bar chart

# %%
df['rank'].value_counts().plot.bar(color=['orange', 'royalblue', 'green'])
plt.title("Rank Frequency")
plt.xlabel('Designation')
plt.ylabel('Count')
plt.ylim(0,300)
plt.grid(which='both')
# plt.minorticks_on()
# plt.xscale('log')
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
df['rank'].value_counts().plot.pie(autopct='%.2f')
# df['salary'].value_counts().plot.pie(autopct='%.2f')
plt.show()

# %% [markdown]
# ### HISTOGRAM

# %% [markdown]
# #### Based on mean of the column

# %%
df['salary'].plot.hist()
plt.axvline(df['salary'].mean(),color='r')  # ax-vertical line on graph
plt.xlabel("salary")
plt.show()

# %%
df['salary'].plot.hist(bins=3)
plt.axvline(df['salary'].mean(),color='r')  # ax-vertical line on graph
plt.xlabel("salary")
plt.grid()
plt.show()

# Longer tail on right side: Right Skewed
# No. of elements more than MEAN are more in number

# %% [markdown]
# #### Based on Median (Box-plot)

# %%
df['salary'].plot.box()
plt.xlabel("salary")
plt.grid()
plt.show()

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ### Using 2 Variables

# %%
plt.scatter(df['salary'], df['yrs.service'], c='r')
plt.show()

# %%
plt.scatter(df['salary'], df['yrs.since.phd'], c='g', marker="*")
plt.show()

# %%
plt.scatter(df['yrs.service'], df['yrs.since.phd'], c='darkblue', marker='+')
plt.show()

# %%
df.corr()
# Out:
# /var/folders/nk/ln22svl57cz_cvk82jt3d1kh0000gn/T/ipykernel_41218/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                Unnamed: 0  yrs.since.phd  yrs.service    salary
# Unnamed: 0       1.000000       0.208424     0.166314  0.099583
# yrs.since.phd    0.208424       1.000000     0.909649  0.419231
# yrs.service      0.166314       0.909649     1.000000  0.334745
# salary           0.099583       0.419231     0.334745  1.000000

# %%
df['salary'].plot.line()
plt.show()

# %%
op = pd.DataFrame({"yearsService" : df['yrs.service'], "yearsSincePHD" : df['yrs.since.phd']})
op.plot.line(linestyle="dashdot")
plt.show()
